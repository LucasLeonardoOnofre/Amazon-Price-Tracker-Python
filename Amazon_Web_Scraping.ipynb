# %% [markdown]
# Amazon Web Scraper-  Project - Python

# %%
# Importing necessary libraries
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# %%
# Connect to Amazon Website
# Product URL to scrape
URL = 'https://www.amazon.com.au/Driven-Analyst-Teacher-Unisex-T-Shirt/dp/B0DXHTMGMR/ref=sr_1_2?crid=3IYM8961GJUE6&dib=eyJ2IjoiMSJ9.h3UZVfD5SUTecPmScW4ajxPnWWmyPrkSaVFXZsTpuPRDf1n6xbR5Nhr3BuoQFBLydFUQV4O1C_4JUH7MeSPUPjQowcRDJfPpG3vqS_jz6ZHJRjtnJbKIroVPBAa85N117GgXGA8HzZXAu_o4wlkXE9tG0RMpy1izEL3A_ndh-vp0KXTfmDEFGcWbwmSF-tcyWURrm6as5mDJ-qP2sRXZEvMJIR-34aoB-EWmDDQVEsw20LMo_4RXRP2b1IUSVnUI9_nHB3Y1UmcGJcOUnhn95It97T4NW6pMifRhH16pBb0.AzgJkbJ4Z3E28M04x8mebgGNEMShNx-zHt4k-STTve0&dib_tag=se&keywords=Data%2BAnalyst%2BT-Shirt&qid=1768808703&sprefix=data%2Banalyst%2Bt-shir%2Caps%2C391&sr=8-2&th=1&psc=1'
# Headers to mimic a real browser request (avoids being blocked)
headers = {"User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) " "AppleWebKit/537.36 (KHTML, like Gecko) " "Chrome/120.0.0.0 Safari/537.36")}
# Send GET request to the webpage
page = requests.get(URL, headers = headers)
# Parse the HTML content
soup = BeautifulSoup(page.content, 'html.parser')
soup1 = BeautifulSoup(soup.prettify(),'html.parser') # Better formatting
# # Extract product information from the Webpage
title = soup1.find (id = 'productTitle').get_text()
title = title.strip()
whole = soup1.find("span", class_="a-price-whole").get_text(strip=True)
decimal = soup1.find("span", class_="a-price-fraction").get_text(strip=True)
price = whole + decimal # Printing Price & Title
print(title)
print(price)
# Out:
# That Wasn't Very Data Driven of You Data Analyst Teacher Unisex Shirt Gift Women Men
# 37.47

# %%
today = datetime.date.today() # Get today's date
print(today)
# Out:
# 2026-01-20

# %%
header = ['Title', 'Price','Date']
data = [title,price,today]
type(data)
# Creating a csv file
with open ('AmazonWebScraperDataset.csv','w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
# Checking updates
df = pd.read_csv(r'C:\Users\lucas\Documents\Projects\Python\Amazon Web Scraping Python\AmazonWebScraperDataset.csv')
print(df)
# Out:
#                                                Title  Price        Date
# 0  That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20

# %%
#  Appending data to the csv
with open ('AmazonWebScraperDataset.csv','a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
# Function to check price repeatedly
def check_price():
    URL = 'https://www.amazon.com.au/Driven-Analyst-Teacher-Unisex-T-Shirt/dp/B0DXHTMGMR/ref=sr_1_2?crid=3IYM8961GJUE6&dib=eyJ2IjoiMSJ9.h3UZVfD5SUTecPmScW4ajxPnWWmyPrkSaVFXZsTpuPRDf1n6xbR5Nhr3BuoQFBLydFUQV4O1C_4JUH7MeSPUPjQowcRDJfPpG3vqS_jz6ZHJRjtnJbKIroVPBAa85N117GgXGA8HzZXAu_o4wlkXE9tG0RMpy1izEL3A_ndh-vp0KXTfmDEFGcWbwmSF-tcyWURrm6as5mDJ-qP2sRXZEvMJIR-34aoB-EWmDDQVEsw20LMo_4RXRP2b1IUSVnUI9_nHB3Y1UmcGJcOUnhn95It97T4NW6pMifRhH16pBb0.AzgJkbJ4Z3E28M04x8mebgGNEMShNx-zHt4k-STTve0&dib_tag=se&keywords=Data%2BAnalyst%2BT-Shirt&qid=1768808703&sprefix=data%2Banalyst%2Bt-shir%2Caps%2C391&sr=8-2&th=1&psc=1'

    headers = {"User-Agent": ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) " "AppleWebKit/537.36 (KHTML, like Gecko) " "Chrome/120.0.0.0 Safari/537.36")}

    page = requests.get(URL, headers = headers)

    soup = BeautifulSoup(page.content, 'html.parser')
    soup1 = BeautifulSoup(soup.prettify(),'html.parser') # Better formatting
    # Pulling values from the Webpage
    title = soup1.find (id = 'productTitle').get_text()
    title = title.strip()
    whole = soup1.find("span", class_="a-price-whole").get_text(strip=True)
    decimal = soup1.find("span", class_="a-price-fraction").get_text(strip=True)
    price = whole + decimal # Printing Price & Title
    today = datetime.date.today()
    header = ['Title', 'Price','Date']
    data = [title,price,today]

    with open ('AmazonWebScraperDataset.csv','a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
#Continuously check price every 10 seconds
while(True):
    check_price()
    time.sleep(10)

# %%
# Checking updates
df = pd.read_csv(r'C:\Users\lucas\Documents\Projects\Python\Amazon Web Scraping Python\AmazonWebScraperDataset.csv')
print(df)
# Out:
#                                                 Title  Price        Date
# 0   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 1   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 2   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 3   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 4   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 5   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 6   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 7   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 8   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 9   That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 10  That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# 11  That Wasn't Very Data Driven of You Data Analy...  37.47  2026-01-20
# ...
